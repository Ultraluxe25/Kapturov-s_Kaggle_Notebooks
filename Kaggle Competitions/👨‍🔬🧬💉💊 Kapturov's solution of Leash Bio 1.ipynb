# %% [markdown]
# <a href="https://www.kaggle.com/code/kapturovalexander/kapturov-s-solution-of-leash-bio-1?scriptVersionId=170652764" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ![](https://www.kaggle.com/competitions/67356/images/header)

# %% [markdown]
# ### My notebook is enspired by Andrew D. Blevins and his notebook [Leash Tutorial - ECFPs and Random Forest](https://www.kaggle.com/code/andrewdblevins/leash-tutorial-ecfps-and-random-forest)

# %% [markdown]
# ### I will change all his code in my notebook later after I completely figure out with competition

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/leash-BELKA/sample_submission.csv
# /kaggle/input/leash-BELKA/train.parquet
# /kaggle/input/leash-BELKA/test.parquet
# /kaggle/input/leash-BELKA/train.csv
# /kaggle/input/leash-BELKA/test.csv

# %%
# %%time
# !pip install rdkit
# !pip install duckdb
print('OK')
# Out:
# Collecting rdkit
#   Downloading rdkit-2023.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from rdkit) (1.26.4)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from rdkit) (9.5.0)
# Downloading rdkit-2023.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 38.5 MB/s eta 0:00:00
# Installing collected packages: rdkit
# Successfully installed rdkit-2023.9.5
# Collecting duckdb
#   Downloading duckdb-0.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (763 bytes)
# Downloading duckdb-0.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 60.2 MB/s eta 0:00:00
# Installing collected packages: duckdb
# Successfully installed duckdb-0.10.1
# OK
# CPU times: user 703 ms, sys: 122 ms, total: 825 ms
# Wall time: 35.3 s

# %% [markdown]
# ![](https://www.chitkara.edu.in/blogs/wp-content/uploads/2023/03/Medicinal-Chemistry-vs-Pharmaceutics.jpg)

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import duckdb
import optuna
from optuna.samplers import TPESampler
import pickle
from rdkit import Chem
from rdkit.Chem import AllChem
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import StackingClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn.metrics import average_precision_score

# %%
# %%time
train_path = '/kaggle/input/leash-BELKA/train.parquet'
test_path = '/kaggle/input/leash-BELKA/test.parquet'

con = duckdb.connect()

df = con.query(f"""(SELECT *
                        FROM parquet_scan('{train_path}')
                        WHERE binds = 0
                        ORDER BY random()
                        LIMIT 30000)
                        UNION ALL
                        (SELECT *
                        FROM parquet_scan('{train_path}')
                        WHERE binds = 1
                        ORDER BY random()
                        LIMIT 30000)""").df()

con.close()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# CPU times: user 2min 53s, sys: 9.03 s, total: 3min 2s
# Wall time: 55 s

# %%
df.head()
# Out:
#           id                              buildingblock1_smiles  \
# 0  215644791  O=C(Nc1cccc([N+](=O)[O-])c1C(=O)O)OCC1c2ccccc2...
# 1  246970016  O=C(O)C[C@@H](Cc1ccc(Cl)cc1)NC(=O)OCC1c2ccccc2...
# 2  208666735     O=C(Nc1cccc(Br)c1C(=O)O)OCC1c2ccccc2-c2ccccc21
# 3  275331846  O=C(O)C[C@H](NC(=O)OCC1c2ccccc2-c2ccccc21)c1cc...
# 4   97353741  O=C(N[C@@H](Cc1ccc(F)c(F)c1)C(=O)O)OCC1c2ccccc...
#
#     buildingblock2_smiles  buildingblock3_smiles  \
# 0             Nc1cn[nH]c1            Cc1csc(N)n1
# 1       NCC1CCC(C(F)F)CC1     Nc1nc(Br)cn2ccnc12
# 2  Cl.NCC1CCOC2(CCOCC2)C1            Nc1nnc(S)s1
# 3        NCCc1coc2ccccc12     COc1ccc2nc(N)sc2c1
# 4            Cc1ccc(N)nn1  CC(C)(C)c1cc(N)n[nH]1
#
#                                      molecule_smiles protein_name  binds
# 0  Cc1csc(Nc2nc(Nc3cn[nH]c3)nc(Nc3cccc([N+](=O)[O...         BRD4      0
# 1  O=C(C[C@@H](Cc1ccc(Cl)cc1)Nc1nc(NCC2CCC(C(F)F)...          sEH      0
# 2  O=C(N[Dy])c1c(Br)cccc1Nc1nc(NCC2CCOC3(CCOCC3)C...          HSA      0
# 3  COc1ccc2nc(Nc3nc(NCCc4coc5ccccc45)nc(N[C@@H](C...         BRD4      0
# 4  Cc1ccc(Nc2nc(Nc3cc(C(C)(C)C)[nH]n3)nc(N[C@@H](...         BRD4      0

# %% [markdown]
# ![](https://previews.123rf.com/images/olegdudko/olegdudko1712/olegdudko171200585/91056161-chemistry-science-formula-and-tablets-medicine-symbol.jpg)

# %%
# %%time
# Convert SMILES to RDKit molecules
df['molecule'] = df['molecule_smiles'].apply(Chem.MolFromSmiles)

# Generate ECFPs
def generate_ecfp(molecule, radius=2, bits=1024):
    if molecule is None:
        return None
    return list(AllChem.GetMorganFingerprintAsBitVect(molecule, radius, nBits=bits))

df['ecfp'] = df['molecule'].apply(generate_ecfp)
# Out:
# CPU times: user 1min 44s, sys: 2.24 s, total: 1min 46s
# Wall time: 1min 46s

# %%
# %%time
# One-hot encode the protein_name
onehot_encoder = OneHotEncoder(sparse_output=False)
protein_onehot = onehot_encoder.fit_transform(df['protein_name'].values.reshape(-1, 1))

# Combine ECFPs and one-hot encoded protein_name
X = [ecfp + protein for ecfp, protein in zip(df['ecfp'].tolist(), protein_onehot.tolist())]
y = df['binds'].tolist()

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=27)

# Create and train the random forest model
rf_model = CatBoostClassifier(iterations=500, random_state=27)
rf_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred_proba = rf_model.predict_proba(X_test)[:, 1]  # Probability of the positive class

# Calculate the mean average precision
map_score = average_precision_score(y_test, y_pred_proba)
print(f"Mean Average Precision (mAP): {map_score:.8f}")
# Out:
# Learning rate set to 0.101594
# 0:	learn: 0.6587357	total: 115ms	remaining: 57.4s
# 1:	learn: 0.6294139	total: 179ms	remaining: 44.6s
# 2:	learn: 0.6046120	total: 232ms	remaining: 38.4s
# 3:	learn: 0.5868222	total: 284ms	remaining: 35.2s
# 4:	learn: 0.5713043	total: 340ms	remaining: 33.6s
# 5:	learn: 0.5588001	total: 388ms	remaining: 32s
# 6:	learn: 0.5439851	total: 436ms	remaining: 30.7s
# 7:	learn: 0.5358505	total: 492ms	remaining: 30.3s
# 8:	learn: 0.5254938	total: 568ms	remaining: 31s
# 9:	learn: 0.5184722	total: 619ms	remaining: 30.3s
# 10:	learn: 0.5123025	total: 667ms	remaining: 29.7s
# 11:	learn: 0.5056592	total: 716ms	remaining: 29.1s
# 12:	learn: 0.5006843	total: 761ms	remaining: 28.5s
# 13:	learn: 0.4967700	total: 807ms	remaining: 28s
# 14:	learn: 0.4932327	total: 852ms	remaining: 27.5s
# 247:	learn: 0.2587241	total: 12.2s	remaining: 12.4s
# 248:	learn: 0.2584018	total: 12.3s	remaining: 12.4s
# 249:	learn: 0.2581593	total: 12.3s	remaining: 12.3s
# 250:	learn: 0.2578822	total: 12.4s	remaining: 12.3s
# 251:	learn: 0.2575298	total: 12.4s	remaining: 12.2s
# 252:	learn: 0.2571040	total: 12.5s	remaining: 12.2s
# 253:	learn: 0.2568598	total: 12.5s	remaining: 12.1s
# 254:	learn: 0.2565333	total: 12.6s	remaining: 12.1s
# 255:	learn: 0.2559463	total: 12.6s	remaining: 12s
# 256:	learn: 0.2556492	total: 12.6s	remaining: 12s
# 257:	learn: 0.2553650	total: 12.7s	remaining: 11.9s
# 258:	learn: 0.2550335	total: 12.7s	remaining: 11.9s
# 259:	learn: 0.2547269	total: 12.8s	remaining: 11.8s
# 260:	learn: 0.2544125	total: 12.8s	remaining: 11.8s
# 261:	learn: 0.2540202	total: 12.9s	remaining: 11.7s
# 262:	learn: 0.2538074	total: 12.9s	remaining: 11.6s
# 263:	learn: 0.2535945	total: 13s	remaining: 11.6s
# 264:	learn: 0.2532854	total: 13s	remaining: 11.5s
# 265:	learn: 0.2526914	total: 13.1s	remaining: 11.5s
# 266:	learn: 0.2524431	total: 13.1s	remaining: 11.4s
# 267:	learn: 0.2520546	total: 13.2s	remaining: 11.4s
# 268:	learn: 0.2516168	total: 13.2s	remaining: 11.3s
# 269:	learn: 0.2513016	total: 13.3s	remaining: 11.3s
# 270:	learn: 0.2510671	total: 13.3s	remaining: 11.2s
# 271:	learn: 0.2507962	total: 13.3s	remaining: 11.2s
# 272:	learn: 0.2505808	total: 13.4s	remaining: 11.1s
# 273:	learn: 0.2503026	total: 13.4s	remaining: 11.1s
# 274:	learn: 0.2500812	total: 13.5s	remaining: 11s
# 275:	learn: 0.2497810	total: 13.5s	remaining: 11s
# 276:	learn: 0.2494805	total: 13.6s	remaining: 10.9s
# 277:	learn: 0.2492434	total: 13.6s	remaining: 10.9s
# 278:	learn: 0.2490474	total: 13.7s	remaining: 10.8s
# 279:	learn: 0.2487307	total: 13.7s	remaining: 10.8s
# 280:	learn: 0.2484536	total: 13.8s	remaining: 10.7s
# 281:	learn: 0.2481007	total: 13.8s	remaining: 10.7s
# 282:	learn: 0.2478395	total: 13.9s	remaining: 10.6s
# 283:	learn: 0.2475190	total: 13.9s	remaining: 10.6s
# 284:	learn: 0.2471211	total: 13.9s	remaining: 10.5s
# 285:	learn: 0.2468460	total: 14s	remaining: 10.5s
# 286:	learn: 0.2466010	total: 14s	remaining: 10.4s
# 287:	learn: 0.2462964	total: 14.1s	remaining: 10.4s
# 288:	learn: 0.2460460	total: 14.1s	remaining: 10.3s
# 289:	learn: 0.2457503	total: 14.2s	remaining: 10.3s
# 290:	learn: 0.2455568	total: 14.2s	remaining: 10.2s
# 291:	learn: 0.2452570	total: 14.3s	remaining: 10.2s
# 292:	learn: 0.2449511	total: 14.3s	remaining: 10.1s
# 293:	learn: 0.2446521	total: 14.4s	remaining: 10.1s
# 294:	learn: 0.2443316	total: 14.4s	remaining: 10s
# 295:	learn: 0.2440703	total: 14.4s	remaining: 9.96s
# 296:	learn: 0.2436645	total: 14.5s	remaining: 9.9s
# 297:	learn: 0.2434295	total: 14.5s	remaining: 9.85s
# 298:	learn: 0.2431974	total: 14.6s	remaining: 9.8s
# 299:	learn: 0.2429407	total: 14.6s	remaining: 9.75s
# 300:	learn: 0.2426318	total: 14.7s	remaining: 9.7s
# 301:	learn: 0.2423780	total: 14.7s	remaining: 9.65s
# 302:	learn: 0.2419102	total: 14.8s	remaining: 9.61s
# 303:	learn: 0.2416466	total: 14.8s	remaining: 9.55s
# 304:	learn: 0.2414212	total: 14.9s	remaining: 9.51s
# 305:	learn: 0.2411940	total: 14.9s	remaining: 9.46s
# 306:	learn: 0.2409513	total: 15s	remaining: 9.4s
# 307:	learn: 0.2406897	total: 15s	remaining: 9.36s
# 308:	learn: 0.2404823	total: 15.1s	remaining: 9.3s
# 309:	learn: 0.2402874	total: 15.1s	remaining: 9.26s
# 310:	learn: 0.2399995	total: 15.1s	remaining: 9.2s
# 311:	learn: 0.2397861	total: 15.2s	remaining: 9.15s
# 312:	learn: 0.2395371	total: 15.2s	remaining: 9.1s
# 313:	learn: 0.2392959	total: 15.3s	remaining: 9.05s
# 314:	learn: 0.2390794	total: 15.3s	remaining: 9.01s
# 315:	learn: 0.2388223	total: 15.4s	remaining: 8.95s
# 316:	learn: 0.2385884	total: 15.4s	remaining: 8.9s
# 317:	learn: 0.2383668	total: 15.5s	remaining: 8.85s
# 318:	learn: 0.2381374	total: 15.5s	remaining: 8.8s
# 319:	learn: 0.2379011	total: 15.6s	remaining: 8.75s
# 320:	learn: 0.2374698	total: 15.6s	remaining: 8.7s
# 321:	learn: 0.2371853	total: 15.7s	remaining: 8.65s
# 322:	learn: 0.2369947	total: 15.7s	remaining: 8.6s
# 323:	learn: 0.2368189	total: 15.7s	remaining: 8.55s
# 324:	learn: 0.2364954	total: 15.8s	remaining: 8.5s
# 325:	learn: 0.2361973	total: 15.8s	remaining: 8.46s
# 326:	learn: 0.2359952	total: 15.9s	remaining: 8.4s
# 327:	learn: 0.2357874	total: 15.9s	remaining: 8.36s
# 328:	learn: 0.2355836	total: 16s	remaining: 8.3s
# 329:	learn: 0.2352829	total: 16s	remaining: 8.26s
# 330:	learn: 0.2350154	total: 16.1s	remaining: 8.21s
# 331:	learn: 0.2348104	total: 16.1s	remaining: 8.16s
# 332:	learn: 0.2345481	total: 16.2s	remaining: 8.11s
# 333:	learn: 0.2342720	total: 16.2s	remaining: 8.06s
# 334:	learn: 0.2339901	total: 16.3s	remaining: 8.01s
# 335:	learn: 0.2338125	total: 16.3s	remaining: 7.96s
# 336:	learn: 0.2336018	total: 16.4s	remaining: 7.91s
# 337:	learn: 0.2333102	total: 16.4s	remaining: 7.86s
# 338:	learn: 0.2330964	total: 16.4s	remaining: 7.81s
# 339:	learn: 0.2328405	total: 16.5s	remaining: 7.76s
# 340:	learn: 0.2326314	total: 16.5s	remaining: 7.71s
# 341:	learn: 0.2324413	total: 16.6s	remaining: 7.66s
# 342:	learn: 0.2321083	total: 16.6s	remaining: 7.61s
# 343:	learn: 0.2319223	total: 16.7s	remaining: 7.56s
# 344:	learn: 0.2317121	total: 16.7s	remaining: 7.51s
# 345:	learn: 0.2313438	total: 16.8s	remaining: 7.46s
# 346:	learn: 0.2310926	total: 16.8s	remaining: 7.42s
# 347:	learn: 0.2308517	total: 16.9s	remaining: 7.37s
# 348:	learn: 0.2306401	total: 16.9s	remaining: 7.32s
# 349:	learn: 0.2304309	total: 17s	remaining: 7.27s
# 350:	learn: 0.2301814	total: 17s	remaining: 7.22s
# 351:	learn: 0.2300184	total: 17.1s	remaining: 7.17s
# 352:	learn: 0.2298421	total: 17.1s	remaining: 7.12s
# 353:	learn: 0.2296254	total: 17.1s	remaining: 7.07s
# 354:	learn: 0.2293385	total: 17.2s	remaining: 7.02s
# 355:	learn: 0.2290799	total: 17.2s	remaining: 6.97s
# 356:	learn: 0.2287786	total: 17.3s	remaining: 6.93s
# 357:	learn: 0.2284873	total: 17.3s	remaining: 6.88s
# 358:	learn: 0.2282103	total: 17.4s	remaining: 6.83s
# 359:	learn: 0.2280038	total: 17.4s	remaining: 6.78s
# 360:	learn: 0.2277480	total: 17.5s	remaining: 6.73s
# 361:	learn: 0.2275885	total: 17.5s	remaining: 6.68s
# 362:	learn: 0.2274085	total: 17.6s	remaining: 6.63s
# 363:	learn: 0.2271849	total: 17.6s	remaining: 6.58s
# 364:	learn: 0.2269684	total: 17.7s	remaining: 6.53s
# 365:	learn: 0.2268178	total: 17.7s	remaining: 6.48s
# 366:	learn: 0.2265878	total: 17.8s	remaining: 6.43s
# 367:	learn: 0.2263997	total: 17.8s	remaining: 6.38s
# 368:	learn: 0.2262078	total: 17.8s	remaining: 6.33s
# 369:	learn: 0.2260274	total: 17.9s	remaining: 6.29s
# 370:	learn: 0.2258416	total: 17.9s	remaining: 6.24s
# 371:	learn: 0.2256646	total: 18s	remaining: 6.19s
# 372:	learn: 0.2254371	total: 18s	remaining: 6.14s
# 373:	learn: 0.2252166	total: 18.1s	remaining: 6.09s
# 374:	learn: 0.2250086	total: 18.1s	remaining: 6.04s
# 375:	learn: 0.2248370	total: 18.2s	remaining: 5.99s
# 376:	learn: 0.2246732	total: 18.2s	remaining: 5.94s
# 377:	learn: 0.2244293	total: 18.3s	remaining: 5.9s
# 378:	learn: 0.2242471	total: 18.3s	remaining: 5.85s
# 379:	learn: 0.2239960	total: 18.4s	remaining: 5.8s
# 380:	learn: 0.2237917	total: 18.4s	remaining: 5.75s
# 381:	learn: 0.2235779	total: 18.5s	remaining: 5.7s
# 382:	learn: 0.2234225	total: 18.5s	remaining: 5.65s
# 383:	learn: 0.2232369	total: 18.5s	remaining: 5.6s
# 384:	learn: 0.2230484	total: 18.6s	remaining: 5.55s
# 385:	learn: 0.2228670	total: 18.6s	remaining: 5.5s
# 386:	learn: 0.2226345	total: 18.7s	remaining: 5.45s
# 387:	learn: 0.2224392	total: 18.7s	remaining: 5.41s
# 388:	learn: 0.2222367	total: 18.8s	remaining: 5.36s
# 389:	learn: 0.2220722	total: 18.8s	remaining: 5.31s
# 390:	learn: 0.2219048	total: 18.9s	remaining: 5.26s
# 391:	learn: 0.2217075	total: 18.9s	remaining: 5.21s
# 392:	learn: 0.2214758	total: 19s	remaining: 5.16s
# 393:	learn: 0.2213041	total: 19s	remaining: 5.11s
# 394:	learn: 0.2211279	total: 19s	remaining: 5.06s
# 395:	learn: 0.2210022	total: 19.1s	remaining: 5.01s
# 396:	learn: 0.2208732	total: 19.1s	remaining: 4.96s
# 397:	learn: 0.2206799	total: 19.2s	remaining: 4.92s
# 398:	learn: 0.2204155	total: 19.2s	remaining: 4.87s
# 399:	learn: 0.2199527	total: 19.3s	remaining: 4.82s
# 400:	learn: 0.2197678	total: 19.3s	remaining: 4.77s
# 401:	learn: 0.2196012	total: 19.4s	remaining: 4.72s
# 402:	learn: 0.2193861	total: 19.4s	remaining: 4.67s
# 403:	learn: 0.2192161	total: 19.5s	remaining: 4.63s
# 404:	learn: 0.2190206	total: 19.5s	remaining: 4.58s
# 405:	learn: 0.2188321	total: 19.6s	remaining: 4.53s
# 406:	learn: 0.2185455	total: 19.6s	remaining: 4.48s
# 407:	learn: 0.2183487	total: 19.7s	remaining: 4.43s
# 408:	learn: 0.2181950	total: 19.7s	remaining: 4.38s
# 409:	learn: 0.2180235	total: 19.8s	remaining: 4.34s
# 410:	learn: 0.2178601	total: 19.8s	remaining: 4.29s
# 411:	learn: 0.2176533	total: 19.8s	remaining: 4.24s
# 412:	learn: 0.2174571	total: 19.9s	remaining: 4.19s
# 413:	learn: 0.2173257	total: 19.9s	remaining: 4.14s
# 414:	learn: 0.2171257	total: 20s	remaining: 4.09s
# 415:	learn: 0.2169304	total: 20s	remaining: 4.04s
# 416:	learn: 0.2167869	total: 20.1s	remaining: 4s
# 417:	learn: 0.2165842	total: 20.1s	remaining: 3.95s
# 418:	learn: 0.2164404	total: 20.2s	remaining: 3.9s
# 419:	learn: 0.2162359	total: 20.2s	remaining: 3.85s
# 420:	learn: 0.2161158	total: 20.3s	remaining: 3.8s
# 421:	learn: 0.2158985	total: 20.3s	remaining: 3.75s
# 422:	learn: 0.2157205	total: 20.4s	remaining: 3.71s
# 423:	learn: 0.2154445	total: 20.4s	remaining: 3.66s
# 424:	learn: 0.2152906	total: 20.5s	remaining: 3.62s
# 425:	learn: 0.2149401	total: 20.6s	remaining: 3.57s
# 426:	learn: 0.2147700	total: 20.6s	remaining: 3.52s
# 427:	learn: 0.2145975	total: 20.6s	remaining: 3.47s
# 428:	learn: 0.2142808	total: 20.7s	remaining: 3.42s
# 429:	learn: 0.2140586	total: 20.7s	remaining: 3.38s
# 430:	learn: 0.2138874	total: 20.8s	remaining: 3.33s
# 431:	learn: 0.2137407	total: 20.8s	remaining: 3.28s
# 432:	learn: 0.2135137	total: 20.9s	remaining: 3.23s
# 433:	learn: 0.2133309	total: 20.9s	remaining: 3.18s
# 434:	learn: 0.2131751	total: 21s	remaining: 3.13s
# 435:	learn: 0.2130201	total: 21s	remaining: 3.08s
# 436:	learn: 0.2128420	total: 21.1s	remaining: 3.04s
# 437:	learn: 0.2127263	total: 21.1s	remaining: 2.99s
# 438:	learn: 0.2125706	total: 21.2s	remaining: 2.94s
# 439:	learn: 0.2123973	total: 21.2s	remaining: 2.89s
# 440:	learn: 0.2122571	total: 21.2s	remaining: 2.84s
# 441:	learn: 0.2121007	total: 21.3s	remaining: 2.79s
# 442:	learn: 0.2119601	total: 21.3s	remaining: 2.75s
# 443:	learn: 0.2117803	total: 21.4s	remaining: 2.7s
# 444:	learn: 0.2115200	total: 21.4s	remaining: 2.65s
# 445:	learn: 0.2113714	total: 21.5s	remaining: 2.6s
# 446:	learn: 0.2112411	total: 21.5s	remaining: 2.55s
# 447:	learn: 0.2110728	total: 21.6s	remaining: 2.5s
# 448:	learn: 0.2109220	total: 21.6s	remaining: 2.45s
# 449:	learn: 0.2107780	total: 21.7s	remaining: 2.41s
# 450:	learn: 0.2106221	total: 21.7s	remaining: 2.36s
# 451:	learn: 0.2104752	total: 21.7s	remaining: 2.31s
# 452:	learn: 0.2103360	total: 21.8s	remaining: 2.26s
# 453:	learn: 0.2101773	total: 21.8s	remaining: 2.21s
# 454:	learn: 0.2100018	total: 21.9s	remaining: 2.16s
# 455:	learn: 0.2098392	total: 21.9s	remaining: 2.12s
# 456:	learn: 0.2096674	total: 22s	remaining: 2.07s
# 457:	learn: 0.2095462	total: 22s	remaining: 2.02s
# 458:	learn: 0.2093925	total: 22.1s	remaining: 1.97s
# 459:	learn: 0.2092723	total: 22.1s	remaining: 1.92s
# 460:	learn: 0.2091555	total: 22.2s	remaining: 1.87s
# 461:	learn: 0.2089849	total: 22.2s	remaining: 1.83s
# 462:	learn: 0.2087466	total: 22.3s	remaining: 1.78s
# 463:	learn: 0.2085462	total: 22.3s	remaining: 1.73s
# 464:	learn: 0.2083261	total: 22.4s	remaining: 1.68s
# 465:	learn: 0.2081247	total: 22.4s	remaining: 1.63s
# 466:	learn: 0.2079197	total: 22.4s	remaining: 1.59s
# 467:	learn: 0.2077315	total: 22.5s	remaining: 1.54s
# 468:	learn: 0.2076140	total: 22.5s	remaining: 1.49s
# 469:	learn: 0.2073652	total: 22.6s	remaining: 1.44s
# 470:	learn: 0.2072447	total: 22.6s	remaining: 1.39s
# 471:	learn: 0.2071099	total: 22.7s	remaining: 1.34s
# 472:	learn: 0.2068925	total: 22.7s	remaining: 1.3s
# 473:	learn: 0.2067526	total: 22.8s	remaining: 1.25s
# 474:	learn: 0.2066314	total: 22.8s	remaining: 1.2s
# 475:	learn: 0.2064617	total: 22.9s	remaining: 1.15s
# 476:	learn: 0.2063159	total: 22.9s	remaining: 1.1s
# 477:	learn: 0.2060946	total: 23s	remaining: 1.06s
# 478:	learn: 0.2059457	total: 23s	remaining: 1.01s
# 479:	learn: 0.2057499	total: 23s	remaining: 960ms
# 480:	learn: 0.2055983	total: 23.1s	remaining: 912ms
# 481:	learn: 0.2054454	total: 23.1s	remaining: 864ms
# 482:	learn: 0.2053292	total: 23.2s	remaining: 816ms
# 483:	learn: 0.2051488	total: 23.2s	remaining: 768ms
# 484:	learn: 0.2050046	total: 23.3s	remaining: 720ms
# 485:	learn: 0.2048238	total: 23.3s	remaining: 672ms
# 486:	learn: 0.2046234	total: 23.4s	remaining: 624ms
# 487:	learn: 0.2044751	total: 23.4s	remaining: 576ms
# 488:	learn: 0.2043383	total: 23.5s	remaining: 528ms
# 489:	learn: 0.2041926	total: 23.5s	remaining: 480ms
# 490:	learn: 0.2040492	total: 23.6s	remaining: 432ms
# 491:	learn: 0.2037627	total: 23.6s	remaining: 384ms
# 492:	learn: 0.2036125	total: 23.6s	remaining: 336ms
# 493:	learn: 0.2033950	total: 23.7s	remaining: 288ms
# 494:	learn: 0.2031955	total: 23.7s	remaining: 240ms
# 495:	learn: 0.2030581	total: 23.8s	remaining: 192ms
# 496:	learn: 0.2029345	total: 23.8s	remaining: 144ms
# 497:	learn: 0.2028324	total: 23.9s	remaining: 95.9ms
# 498:	learn: 0.2026416	total: 23.9s	remaining: 48ms
# 499:	learn: 0.2024459	total: 24s	remaining: 0us
# Mean Average Precision (mAP): 0.97179524
# CPU times: user 2min 7s, sys: 6.08 s, total: 2min 13s
# Wall time: 1min 4s

# %% [markdown]
# ![](https://ars.els-cdn.com/content/image/1-s2.0-S2001037020304967-gr3.jpg)

# %%
# %%time
# Process the test.parquet file chunk by chunk
test_file = '/kaggle/input/leash-BELKA/test.csv'
output_file = 'submission.csv'  # Specify the path and filename for the output file

# Read the test.parquet file into a pandas DataFrame
# Wrap the loop with tqdm to display progress
for df_test in tqdm(pd.read_csv(test_file, chunksize=10_000)):
    
    # Generate ECFPs for the molecule_smiles
    df_test['molecule'] = df_test['molecule_smiles'].apply(Chem.MolFromSmiles)
    df_test['ecfp'] = df_test['molecule'].apply(generate_ecfp)

    # One-hot encode the protein_name
    protein_onehot = onehot_encoder.transform(df_test['protein_name'].values.reshape(-1, 1))

    # Combine ECFPs and one-hot encoded protein_name
    X_test = [ecfp + protein for ecfp, protein in zip(df_test['ecfp'].tolist(), protein_onehot.tolist())]

    # Predict the probabilities
    probabilities = rf_model.predict_proba(X_test)[:, 1]

    # Create a DataFrame with 'id' and 'probability' columns
    output_df = pd.DataFrame({'id': df_test['id'], 'binds': probabilities})

    # Save the output DataFrame to a CSV file
    output_df.to_csv(output_file, index=False, mode='a', header=not os.path.exists(output_file))
# Out:
# 168it [1:11:31, 25.55s/it]
# CPU times: user 1h 11min 9s, sys: 41 s, total: 1h 11min 50s
# Wall time: 1h 11min 31s

# %% [markdown]
# ![](https://m.media-amazon.com/images/I/41Xf5xwc25L._SR600%2C315_PIWhiteStrip%2CBottomLeft%2C0%2C35_SCLZZZZZZZ_FMpng_BG255%2C255%2C255.jpg)
