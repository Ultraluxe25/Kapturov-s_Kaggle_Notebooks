# %% [markdown]
# <a href="https://www.kaggle.com/code/kapturovalexander/kapturov-s-march-ml-mania-2024?scriptVersionId=164827052" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # <span style="border-radius: 50px; background-color: orange; padding: 10px 10px 10px 10px">March Machine Learning Mania 2024</span>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/march-machine-learning-mania-2024/Conferences.csv
# /kaggle/input/march-machine-learning-mania-2024/sample_submission.csv
# /kaggle/input/march-machine-learning-mania-2024/WNCAATourneyDetailedResults.csv
# /kaggle/input/march-machine-learning-mania-2024/WRegularSeasonCompactResults.csv
# /kaggle/input/march-machine-learning-mania-2024/MNCAATourneySeedRoundSlots.csv
# /kaggle/input/march-machine-learning-mania-2024/MRegularSeasonDetailedResults.csv
# /kaggle/input/march-machine-learning-mania-2024/MNCAATourneyCompactResults.csv
# /kaggle/input/march-machine-learning-mania-2024/MGameCities.csv
# /kaggle/input/march-machine-learning-mania-2024/WGameCities.csv
# /kaggle/input/march-machine-learning-mania-2024/MSeasons.csv
# /kaggle/input/march-machine-learning-mania-2024/MSecondaryTourneyTeams.csv
# /kaggle/input/march-machine-learning-mania-2024/2024_tourney_seeds.csv
# /kaggle/input/march-machine-learning-mania-2024/Cities.csv
# ...

# %% [markdown]
# ![](https://variety.com/wp-content/uploads/2023/11/GettyImages-1760793417.jpg?w=1024)

# %% [markdown]
# <span style="color: orange; border-style: solid; border-color: yellow; border-width: 5px;">Version 1:</span> Just played with sample_submission
#
# <span style="color: orange; border-style: solid; border-color: yellow; border-width: 5px;">Version 2:</span> Replaced output sample_submission and tried to switch off the internet connection during learning (I failed to submit)
#
# <span style="color: orange; border-style: solid; border-color: yellow; border-width: 5px;">Versions 3, 5:</span> Finally disabled internet and made sample submit!
#
# <span style="color: orange; border-style: solid; border-color: yellow;  border-width: 5px;">Version 4:</span> Added index=False into df.to_csv() to make success submit
#
# <span style="color: orange; border-style: solid; border-color: yellow;  border-width: 5px;">Version 6:</span> Added files description and little beauty into notebook
#
# <span style="color: orange; border-style: solid; border-color: yellow;  border-width: 5px;">Version 7:</span> Added first 3 stages of typical notebook

# %% [markdown]
# # <span style="background-image: url(https://www.kaggle.com/competitions/70068/images/header); color: white; font-size: 50px; padding: 10px 10px 10px 10px">Evaluation</span>

# %% [markdown]
# Submissions are evaluated by their **Average Bracket Score**.
#
# For both the Men's and Women's tournaments, you will submit a portfolio of bracket predictions. The portfolio should comprise at least 1 and at most 100,000 brackets per tournament. Each bracket will be awarded points based on the number of correct predictions per tournament round: 1, 2, 4, 8, 16, 32 points for each correct prediction in rounds 1, 2, 3, 4, 5, 6, respectively.
#
# The score for each tournament is the average score of all of the predicted brackets for that tournament. The final score is the average of the two tournament scores.
#
# Each team is identified by a three character string of the form {region}{seed}, where {region} is one of 'W', 'X', 'Y', 'Z' and {seed} is a string of digits from 01 to 16. Note that we do not score the play-in games. We will therefore denote by W16 the winner of the game between W16a and W16b, and similarly for any other play-in teams.
#
# The structure of each bracket is defined by its slots. In rounds 1 to 4, each slot is identified by a four-character string of the form 'R{round}{region}{chalk_seed}'. The {chalk_seed} is the seed, from 1 to 8, of the best possible seed that could appear in that slot. For instance, R1W1. The two Final Four (Round 5) slots are R5WX and R5YZ, and the Championship (Round 6) game slot is R6CH. Each bracket must contain a prediction for every tournament slot.
#
# Please see the heading Data Section 5 files: MNCAATourneySlots and WNCAATourneySlots on the Data page for more on tournament slots.
#
# The predictions in each bracket must follow valid tournament paths. In other words, if a team is predicted to win a game in Round N, that team must have also been predicted as the winner of Round N-1 in one of the respective feeder games. The winner of a game in Round 1 must be one of the two teams scheduled to play in that game.

# %% [markdown]
# # <span style="color: white; background-image: url(https://www.kaggle.com/competitions/70068/images/header); border-style: solid; padding: 5px 5px 5px 5px; border-width: 5px;">Files for competition:</span>
#
# **<span style="color: orange">Conferences.csv</span>** - Data about conferences in college basketball.
#
# **<span style="color: orange">sample_submission.csv</span>** - Sample file for submitting result forecasts.
#
# **<span style="color: orange">WNCAATourneyDetailedResults.csv</span>** - Detailed results of the Women's NCAA Tournament.
#
# **<span style="color: orange">WRegularSeasonCompactResults.csv</span>** - Compact results of the Women's regular season.
#
# **<span style="color: orange">MNCAATourneySeedRoundSlots.csv</span>** - Data about NCAA tournament seeding and round slots.
#
# **<span style="color: orange">MRegularSeasonDetailedResults.csv</span>** - Detailed results of the Men's regular season.
#
# **<span style="color: orange">MNCAATourneyCompactResults.csv</span>** - Compact results of the NCAA tournament.
#
# <span style="color: orange">**MGameCities.csv**</span> - Cities where Men's basketball games take place.
#
# <span style="color: orange">**WGameCities.csv**</span> - Cities where Women's basketball games take place.
#
# <span style="color: orange">**MSeasons.csv**</span> - Data about seasons in Men's basketball.
#
# <span style="color: orange">**MSecondaryTourneyTeams.csv**</span> - Teams participating in the secondary NCAA tournament.
#
# <span style="color: orange">**2024_tourney_seeds.csv**</span> - Seeding for the 2024 tournament.
#
# <span style="color: orange">**Cities.csv**</span> - Data about cities where games are held.
#
# <span style="color: orange">**MTeamSpellings.csv**</span> - Variants of team spellings.
#
# <span style="color: orange">**MRegularSeasonCompactResults.csv**</span> - Compact results of the Men's regular season.
#
# <span style="color: orange">**MMasseyOrdinals.csv**</span> - Massey rankings for teams.
#
# <span style="color: orange">**MSecondaryTourneyCompactResults.csv**</span> - Compact results of the secondary NCAA tournament.
#
# <span style="color: orange">**WTeams.csv**</span> - Information about Women's teams.
#
# <span style="color: orange">**MNCAATourneySlots.csv**</span> - Slots for the NCAA tournament.
#
# <span style="color: orange">**MNCAATourneySeeds.csv**</span> - Seeding for the NCAA tournament.
#
# <span style="color: orange">**WNCAATourneyCompactResults.csv**</span> - Compact results of the Women's NCAA tournament.
#
# <span style="color: orange">**WSeasons.csv**</span> - Data about seasons in Women's basketball.
#
# <span style="color: orange">**WNCAATourneySeeds.csv**</span> - Seeding for the Women's NCAA tournament.
#
# <span style="color: orange">**MTeamCoaches.csv**</span> - Information about team coaches in Men's basketball.
#
# <span style="color: orange">**MConferenceTourneyGames.csv**</span> - Results of games in conference tournaments.
#
# <span style="color: orange">**WRegularSeasonDetailedResults.csv**</span> - Detailed results of the Women's regular season.
#
# <span style="color: orange">**MNCAATourneyDetailedResults.csv**</span> - Detailed results of the NCAA tournament.
#
# <span style="color: orange">**WTeamSpellings.csv**</span> - Variants of team spellings for Women's teams.
#
# <span style="color: orange">**MTeamConferences.csv**</span> - Information about team conferences in Men's basketball.
#
# <span style="color: orange">**MTeams.csv**</span> - Information about Men's teams.
#
# <span style="color: orange">**WTeamConferences.csv**</span> - Information about team conferences in Women's basketball.
#
# <span style="color: orange">**fivethirtyeight_ncaa_forecasts_2023.csv**</span> - FiveThirtyEight forecasts for the 2023 NCAA tournament.

# %% [markdown]
# # <span style="background-image: url(https://www.kaggle.com/competitions/70068/images/header); color: white; font-size: 50px; padding: 5px 5px 5px 5px">Table of Contents</span>
#
# 1. [Import libraries](#1)
# 2. [Open data files](#2)
# 3. [Show first 5 lines of train data](#3)
#     - 3.1 [Compare original train and competition train](#3.1)
#     - 3.2 [Concatenate original train with competition train](#3.2)
# 4. [Shapes of train and test data](#4)
# 5. [Display descriptive statistics of train data](#5)
# 6. [Check the number of gaps for each feature](#6)
# 7. [Feature Engineering](#7)
#     - 7.1 [Figure out how much duplicates in data](#7.1)
#     - 7.2 [Remove duplicates from data](#7.2)
#     - 7.3 [One-hot encoding](#7.3)
#     - 7.4 [More plots](#7.4)
# 8. [Display histograms of distribution](#8)
# 9. [Let's count target of train data](#9)
# 10. [Transform the data with log1p](#10)
#     - 10.1 [Pie plot of target](#10.1)
#     - 10.2 [Feature importance](#10.2)
# 11. [Build a heat map of correlations](#11)
# 12. [Define base models with tuned hyperparameters](#12)
# 13. [Defining the meta-model with tuned hyperparameters](#13)
# 14. [Creating and fitting the stacking model](#14)
# 15. [Predict validation set and calculate accuracy score](#15)
# 16. [Predict the test data](#16)
# 17. [Build DataFrame and make submission](#17)
# 18. [Save the model into pickle file](#18)

# %% [markdown]
# <a id='1'></a>
# # <span style="color: #FF6E00; border-bottom: 6px solid #8A3324;background-color: #fadb8c;">🏃‍♀️ 1 - Import libraries</span>

# %%
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics, preprocessing
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
from sklearn.model_selection import train_test_split, RandomizedSearchCV, cross_val_score, KFold, StratifiedKFold, GridSearchCV
from sklearn.linear_model import LogisticRegression, SGDClassifier, LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, make_scorer, precision_score, recall_score, log_loss, mean_squared_error, brier_score_loss
import xgboost
from xgboost import XGBClassifier, plot_importance
from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier, VotingClassifier, GradientBoostingClassifier, StackingClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.feature_selection import SelectFromModel
import optuna
from optuna.samplers import TPESampler
import pickle

# %% [markdown]
# <a id='2'></a>
# # <span style="color: #FF6E00; border-bottom: 6px solid #8A3324;background-color: #fadb8c;">🏃‍♂️ 2 - Open data files

# %%
conferences_data = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/Conferences.csv')
sample_submission = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/sample_submission.csv')
wncaa_tourney_results = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/WNCAATourneyDetailedResults.csv')
wregular_season_results = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/WRegularSeasonCompactResults.csv')
mncaa_seed_round_slots = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/MNCAATourneySeedRoundSlots.csv')
mregular_season_results = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/MRegularSeasonDetailedResults.csv')
mncaa_tourney_results = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/MNCAATourneyCompactResults.csv')
mgame_cities = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/MGameCities.csv')
wgame_cities = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/WGameCities.csv')
mseasons_data = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/MSeasons.csv')
msecondary_tourney_teams = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/MSecondaryTourneyTeams.csv')
tourney_seeds_2024 = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/2024_tourney_seeds.csv')
cities_data = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/Cities.csv')
# mteam_spellings = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/MTeamSpellings.csv')
mregular_season_compact = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/MRegularSeasonCompactResults.csv')
massey_ordinals = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/MMasseyOrdinals.csv')
msecondary_tourney_compact = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/MSecondaryTourneyCompactResults.csv')
wteams_data = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/WTeams.csv')
mncaa_tourney_slots = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/MNCAATourneySlots.csv')
mncaa_tourney_seeds = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/MNCAATourneySeeds.csv')
wncaa_tourney_compact = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/WNCAATourneyCompactResults.csv')
wseasons_data = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/WSeasons.csv')
wncaa_tourney_seeds = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/WNCAATourneySeeds.csv')
mteam_coaches = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/MTeamCoaches.csv')
mconference_tourney_games = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/MConferenceTourneyGames.csv')
wregular_season_detailed = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/WRegularSeasonDetailedResults.csv')
mncaa_tourney_detailed = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/MNCAATourneyDetailedResults.csv')
# wteam_spellings = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/WTeamSpellings.csv')
mteam_conferences = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/MTeamConferences.csv')
mteams_data = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/MTeams.csv')
wteam_conferences = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/WTeamConferences.csv')
fivethirtyeight_forecasts_2023 = pd.read_csv('/kaggle/input/march-machine-learning-mania-2024/fivethirtyeight_ncaa_forecasts_2023.csv')

# %% [markdown]
# <a id='3'></a>
# # <span style="color: #FF6E00; border-bottom: 6px solid #8A3324;background-color: #fadb8c;">🏀 3 - Show first 5 lines of train data</span>

# %%
# Show all properties on display and set style
pd.set_option('display.max_columns', None)
sns.set_style('whitegrid')

print("conferences_data shape:", conferences_data.shape)
print("conferences_data head:")
print(conferences_data.head())

print("\n\n\n")

print("sample_submission shape:", sample_submission.shape)
print("sample_submission head:")
print(sample_submission.head())

print("\n\n\n")

print("wncaa_tourney_results shape:", wncaa_tourney_results.shape)
print("wncaa_tourney_results head:")
print(wncaa_tourney_results.head())

print("\n\n\n")

print("wregular_season_results shape:", wregular_season_results.shape)
print("wregular_season_results head:")
print(wregular_season_results.head())

print("\n\n\n")

print("mncaa_seed_round_slots shape:", mncaa_seed_round_slots.shape)
print("mncaa_seed_round_slots head:")
print(mncaa_seed_round_slots.head())

print("\n\n\n")

print("mregular_season_results shape:", mregular_season_results.shape)
print("mregular_season_results head:")
print(mregular_season_results.head())

print("\n\n\n")

print("mncaa_tourney_results shape:", mncaa_tourney_results.shape)
print("mncaa_tourney_results head:")
print(mncaa_tourney_results.head())

print("\n\n\n")

print("mgame_cities shape:", mgame_cities.shape)
print("mgame_cities head:")
print(mgame_cities.head())

print("\n\n\n")

print("wgame_cities shape:", wgame_cities.shape)
print("wgame_cities head:")
print(wgame_cities.head())

print("\n\n\n")

print("mseasons_data shape:", mseasons_data.shape)
print("mseasons_data head:")
print(mseasons_data.head())

print("\n\n\n")

print("msecondary_tourney_teams shape:", msecondary_tourney_teams.shape)
print("msecondary_tourney_teams head:")
print(msecondary_tourney_teams.head())

print("\n\n\n")

print("tourney_seeds_2024 shape:", tourney_seeds_2024.shape)
print("tourney_seeds_2024 head:")
print(tourney_seeds_2024.head())

print("\n\n\n")

print("cities_data shape:", cities_data.shape)
print("cities_data head:")
print(cities_data.head())

print("\n\n\n")

print("mregular_season_compact shape:", mregular_season_compact.shape)
print("mregular_season_compact head:")
print(mregular_season_compact.head())

print("\n\n\n")

print("massey_ordinals shape:", massey_ordinals.shape)
print("massey_ordinals head:")
print(massey_ordinals.head())

print("\n\n\n")

print("msecondary_tourney_compact shape:", msecondary_tourney_compact.shape)
print("msecondary_tourney_compact head:")
print(msecondary_tourney_compact.head())

print("\n\n\n")

print("wteams_data shape:", wteams_data.shape)
print("wteams_data head:")
print(wteams_data.head())

print("\n\n\n")

print("mncaa_tourney_slots shape:", mncaa_tourney_slots.shape)
print("mncaa_tourney_slots head:")
print(mncaa_tourney_slots.head())

print("\n\n\n")

print("mncaa_tourney_seeds shape:", mncaa_tourney_seeds.shape)
print("mncaa_tourney_seeds head:")
print(mncaa_tourney_seeds.head())

print("\n\n\n")

print("wncaa_tourney_compact shape:", wncaa_tourney_compact.shape)
print("wncaa_tourney_compact head:")
print(wncaa_tourney_compact.head())

print("\n\n\n")

print("wseasons_data shape:", wseasons_data.shape)
print("wseasons_data head:")
print(wseasons_data.head())

print("\n\n\n")

print("wncaa_tourney_seeds shape:", wncaa_tourney_seeds.shape)
print("wncaa_tourney_seeds head:")
print(wncaa_tourney_seeds.head())

print("\n\n\n")

print("mteam_coaches shape:", mteam_coaches.shape)
print("mteam_coaches head:")
print(mteam_coaches.head())

print("\n\n\n")

print("mconference_tourney_games shape:", mconference_tourney_games.shape)
print("mconference_tourney_games head:")
print(mconference_tourney_games.head())

print("\n\n\n")

print("wregular_season_detailed shape:", wregular_season_detailed.shape)
print("wregular_season_detailed head:")
print(wregular_season_detailed.head())

print("\n\n\n")

print("mncaa_tourney_detailed shape:", mncaa_tourney_detailed.shape)
print("mncaa_tourney_detailed head:")
print(mncaa_tourney_detailed.head())

print("\n\n\n")

print("mteam_conferences shape:", mteam_conferences.shape)
print("mteam_conferences head:")
print(mteam_conferences.head())

print("\n\n\n")

print("mteams_data shape:", mteams_data.shape)
print("mteams_data head:")
print(mteams_data.head())

print("\n\n\n")

print("wteam_conferences shape:", wteam_conferences.shape)
print("wteam_conferences head:")
print(wteam_conferences.head())

print("\n\n\n")

print("fivethirtyeight_forecasts_2023 shape:", fivethirtyeight_forecasts_2023.shape)
print("fivethirtyeight_forecasts_2023 head:")
print(fivethirtyeight_forecasts_2023.head())
# Out:
# conferences_data shape: (51, 2)
# conferences_data head:
#   ConfAbbrev                   Description
# 0      a_sun       Atlantic Sun Conference
# 1      a_ten        Atlantic 10 Conference
# 2        aac  American Athletic Conference
# 3        acc     Atlantic Coast Conference
# 4        aec       America East Conference
#
#
#
#
# sample_submission shape: (126, 5)
# sample_submission head:
#    RowId Tournament  Bracket  Slot Team
# 0      0          M        1  R1W1  W01
# 1      1          M        1  R1W8  W08
# 2      2          M        1  R1W5  W05
# 3      3          M        1  R1W4  W04
# 4      4          M        1  R1W6  W06
#
#
#
#
# wncaa_tourney_results shape: (827, 34)
# wncaa_tourney_results head:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2010     138     3124      69     3201      55    N      0    28    57
# 1    2010     138     3173      67     3395      66    N      0    23    59
# ...

# %% [markdown]
# ![](https://cloudfront-us-east-2.images.arcpublishing.com/reuters/TBCVUQQXOFKRLLS24WKCPXU2GE.jpg)

# %%
sample_submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126 entries, 0 to 125
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   RowId       126 non-null    int64
#  1   Tournament  126 non-null    object
#  2   Bracket     126 non-null    int64
#  3   Slot        126 non-null    object
#  4   Team        126 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 5.0+ KB

# %%
sample_submission.shape
# Out:
# (126, 5)

# %%
for column in sample_submission.columns.values:
    print(sample_submission[column].value_counts(), end='\n\n')
# Out:
# RowId
# 0      1
# 79     1
# 92     1
# 91     1
# 90     1
#       ..
# 37     1
# 36     1
# 35     1
# 34     1
# 125    1
# Name: count, Length: 126, dtype: int64
#
# Tournament
# M    63
# W    63
# Name: count, dtype: int64
#
# Bracket
# 1    126
# Name: count, dtype: int64
#
# Slot
# R1W1    2
# R2Z2    2
# R2W3    2
# R2W2    2
# R2X1    2
#        ..
# R1Z5    2
# R1Z4    2
# R1Z6    2
# R1Z3    2
# R6CH    2
# Name: count, Length: 63, dtype: int64
#
# Team
# W01    12
# Y01    10
# X01     8
# Z01     8
# Z02     6
# Y02     6
# W02     6
# X02     6
# X03     4
# Y04     4
# W04     4
# X04     4
# Y03     4
# Z04     4
# Z03     4
# W03     4
# Z05     2
# Z08     2
# Z06     2
# Z07     2
# Y07     2
# W05     2
# Y06     2
# Y05     2
# W08     2
# X07     2
# X06     2
# X05     2
# X08     2
# W07     2
# W06     2
# Y08     2
# Name: count, dtype: int64

# %% [markdown]
# ![](https://deadline.com/wp-content/uploads/2021/07/AP21206509013354.jpg)

# %%
sample_submission.value_counts()
# Out:
# RowId  Tournament  Bracket  Slot  Team
# 0      M           1        R1W1  W01     1
# 79     W           1        R1Y1  Y01     1
# 92     W           1        R1Z3  Z03     1
# 91     W           1        R1Z6  Z06     1
# 90     W           1        R1Z4  Z04     1
#                                          ..
# 37     M           1        R2X4  X04     1
# 36     M           1        R2X1  X01     1
# 35     M           1        R2W2  W02     1
# 34     M           1        R2W3  W03     1
# 125    W           1        R6CH  W01     1
# Name: count, Length: 126, dtype: int64

# %%
sample_submission.to_csv('submission.csv', index=False)

# %% [markdown]
# ![](https://lsusports.net/imgproxy/VCCkWnj06xm2AOil6obXr3tSd-ViI4IuaKEuK9xbfLI/fit/5000/5000/ce/0/aHR0cHM6Ly9zdG9yYWdlLmdvb2dsZWFwaXMuY29tL2xzdXNwb3J0cy1jb20vMjAyMy8wMy83NDQ1MzQzYS1yZWVzZTEuanBn.png)

# %% [markdown]
# # <span style="color: orange">I will add more EDA and nice solution soon. Code above is just a training
